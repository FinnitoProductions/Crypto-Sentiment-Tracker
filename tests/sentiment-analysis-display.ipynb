# %%
# %matplotlib notebook
import finndex

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## NLP

# %%
from finndex.util import webutil
from finndex.sentiment import nlp

txt = webutil.getCNNText("https://www.cnn.com/2019/07/09/investing/bitcoin-price/index.html")
nlp.displaySentimentTxt(txt)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Fear and Greed

# %%
from finndex.sentiment import fearandgreed
from finndex.util import dateutil
import datetime

gauge = fearandgreed.displayFearAndGreedDate(dateutil.getCurrentDateTime())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Fundamental Analysis

# %%
from finndex.fundamental import coinmetrics
from finndex.util import cryptocurrencies

coinmetrics.plotAllCoinMetricsData(cryptocurrencies.Cryptocurrencies.BITCOIN_CASH)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Aggregate Analysis

# %%
from finndex.aggregate import instantaneous

manager = instantaneous.InstantaneousSentimentManager([instantaneous.StaticMetricType.FEAR_AND_GREED, 
                                                       instantaneous.StaticMetricType.TRENDS])
manager.displayGauge()

reading = manager.getReading()
# Out:
# The request failed: Google returned a response with code 400.
# <img src="data:image/png;base64,..." width="640">
# HBox(children=(VBox(children=(Label(value='StaticMetricType.FEAR_AND_GREED'), Label(value='StaticMetricType.TR…

# %%
import finndex
from finndex.aggregate import historical
import datetime
from finndex.util import dateutil, cryptocurrencies

historicalManager = historical.HistoricalSentimentManager([historical.HistoricalMetricType.BLOCK_COUNT,
                                                           historical.HistoricalMetricType.DAILY_ADDRESSES,
                                                           historical.HistoricalMetricType.TRANSACTION_CNT],
                                                          [cryptocurrencies.Cryptocurrencies.BITCOIN, 
                                                           cryptocurrencies.Cryptocurrencies.LITECOIN,
                                                           cryptocurrencies.Cryptocurrencies.ETHEREUM,
                                                           cryptocurrencies.Cryptocurrencies.DOGECOIN],
                                                          startDate = dateutil.getCurrentDateTime() - datetime.timedelta(days=60),
                                                          endDate = dateutil.getCurrentDateTime())

historicalManager.getHistoricalSentiment()
historicalManager.displayGraph()
# Out:
# <img src="data:image/png;base64,..." width="640">
# HBox(children=(VBox(children=(Label(value='HistoricalMetricType.BLOCK_COUNT'), Label(value='HistoricalMetricTy…

# %%
historicalManager.getHistoricalSentiment()
# Out:
# {<Cryptocurrencies.BITCOIN: 'BTC'>: {datetime.date(2019, 5, 28): 0.5825183713870592,
#   datetime.date(2019, 5, 29): 0.5845199146732489,
#   datetime.date(2019, 5, 30): 0.5544229098237801,
#   datetime.date(2019, 5, 31): 0.45337338025698926,
#   datetime.date(2019, 6, 1): 0.5148573168966128,
#   datetime.date(2019, 6, 2): 0.4399025065126549,
#   datetime.date(2019, 6, 3): 0.4449725965620179,
#   datetime.date(2019, 6, 4): 0.5605898003982228,
#   datetime.date(2019, 6, 5): 0.5524034850110898,
#   datetime.date(2019, 6, 6): 0.529139834508934,
#   datetime.date(2019, 6, 7): 0.5340175372035542,
#   datetime.date(2019, 6, 8): 0.4128298163815569,
#   datetime.date(2019, 6, 9): 0.4240587340744839,
#   datetime.date(2019, 6, 10): 0.5209288013156246,
#   datetime.date(2019, 6, 11): 0.5138006369552595,
#   datetime.date(2019, 6, 12): 0.48795311167423017,
#   datetime.date(2019, 6, 13): 0.5470345782418624,
#   datetime.date(2019, 6, 14): 0.595747929257999,
#   datetime.date(2019, 6, 15): 0.5126980264477063,
#   datetime.date(2019, 6, 16): 0.43539835910243563,
#   datetime.date(2019, 6, 17): 0.4897152356900448,
#   datetime.date(2019, 6, 18): 0.5887439843439711,
#   datetime.date(2019, 6, 19): 0.5790629762823256,
#   datetime.date(2019, 6, 20): 0.5105474494344426,
#   datetime.date(2019, 6, 21): 0.5093493757320741,
#   datetime.date(2019, 6, 22): 0.5203546343688501,
#   datetime.date(2019, 6, 23): 0.567246012815871,
#   datetime.date(2019, 6, 24): 0.5985852751049409,
#   datetime.date(2019, 6, 25): 0.5484657417475566,
#   datetime.date(2019, 6, 26): 0.6148099142643267,
#   datetime.date(2019, 6, 27): 0.5406460871182039,
#   datetime.date(2019, 6, 28): 0.6081892857533968,
#   datetime.date(2019, 6, 29): 0.5429851537722595,
#   datetime.date(2019, 6, 30): 0.4695381898309894,
#   datetime.date(2019, 7, 1): 0.5091416695429385,
#   datetime.date(2019, 7, 2): 0.5562924637845879,
#   datetime.date(2019, 7, 3): 0.5772821125567059,
#   datetime.date(2019, 7, 4): 0.5363883483553228,
#   datetime.date(2019, 7, 5): 0.5642104898726297,
#   datetime.date(2019, 7, 6): 0.4848975777526251,
#   datetime.date(2019, 7, 7): 0.44473611006878216,
#   datetime.date(2019, 7, 8): 0.5572169892520555,
#   datetime.date(2019, 7, 9): 0.5262634942441187,
#   datetime.date(2019, 7, 10): 0.48340587276825997,
#   datetime.date(2019, 7, 11): 0.4805066697732865,
#   datetime.date(2019, 7, 12): 0.5514895212981014,
#   datetime.date(2019, 7, 13): 0.43866824781188224,
#   datetime.date(2019, 7, 14): 0.42598905348267335,
#   datetime.date(2019, 7, 15): 0.499450845689425,
#   datetime.date(2019, 7, 16): 0.5267052746558378,
#   datetime.date(2019, 7, 17): 0.47311720171448335,
#   datetime.date(2019, 7, 18): 0.46117488882136093,
#   datetime.date(2019, 7, 19): 0.44396441925779273,
#   datetime.date(2019, 7, 20): 0.47869748500784925,
#   datetime.date(2019, 7, 21): 0.4102572379654186,
#   datetime.date(2019, 7, 22): 0.4732071523478656,
#   datetime.date(2019, 7, 23): 0.4635141966926237,
#   datetime.date(2019, 7, 24): 0.4557292717829603,
#   datetime.date(2019, 7, 25): 0.49236270942999577,
#   datetime.date(2019, 7, 26): 0.48919251815031506,
#   datetime.date(2019, 7, 27): 0.41577027195582483},
#  <Cryptocurrencies.LITECOIN: 'LTC'>: {datetime.date(2019, 5, 28): 0.11040932134087571,
#   datetime.date(2019, 5, 29): 0.1124703571139618,
#   datetime.date(2019, 5, 30): 0.12406636361890429,
#   datetime.date(2019, 5, 31): 0.11403322080871803,
#   datetime.date(2019, 6, 1): 0.09875284996567102,
#   datetime.date(2019, 6, 2): 0.1029879682919107,
#   datetime.date(2019, 6, 3): 0.10077272067527508,
#   datetime.date(2019, 6, 4): 0.10634337123003201,
#   datetime.date(2019, 6, 5): 0.10114696129267892,
#   datetime.date(2019, 6, 6): 0.10834754633528244,
#   datetime.date(2019, 6, 7): 0.11238015326960897,
#   datetime.date(2019, 6, 8): 0.10927142547901073,
#   datetime.date(2019, 6, 9): 0.09940152161973362,
#   datetime.date(2019, 6, 10): 0.12959514684186346,
#   datetime.date(2019, 6, 11): 0.12608310930099742,
#   datetime.date(2019, 6, 12): 0.13468075465911872,
#   datetime.date(2019, 6, 13): 0.1272355054795813,
#   datetime.date(2019, 6, 14): 0.12725431311288904,
#   datetime.date(2019, 6, 15): 0.12051957502607168,
#   datetime.date(2019, 6, 16): 0.11937707676835663,
#   datetime.date(2019, 6, 17): 0.12677719485911432,
#   datetime.date(2019, 6, 18): 0.12631836770606514,
#   datetime.date(2019, 6, 19): 0.12850563543472918,
#   datetime.date(2019, 6, 20): 0.12917956539712935,
#   datetime.date(2019, 6, 21): 0.14006317671356033,
#   datetime.date(2019, 6, 22): 0.1658552396805116,
#   datetime.date(2019, 6, 23): 0.12624899053896027,
#   datetime.date(2019, 6, 24): 0.14535058408144613,
#   datetime.date(2019, 6, 25): 0.13123392470273748,
#   datetime.date(2019, 6, 26): 0.15126810474786911,
#   datetime.date(2019, 6, 27): 0.14180698163249286,
#   datetime.date(2019, 6, 28): 0.12221430771255706,
#   datetime.date(2019, 6, 29): 0.11607429147461397,
#   datetime.date(2019, 6, 30): 0.10450583756112442,
#   datetime.date(2019, 7, 1): 0.11734360837756339,
#   datetime.date(2019, 7, 2): 0.10721645905235633,
#   datetime.date(2019, 7, 3): 0.1113768966397398,
#   datetime.date(2019, 7, 4): 0.10672846727600352,
#   datetime.date(2019, 7, 5): 0.10691870944717716,
#   datetime.date(2019, 7, 6): 0.10308944571109642,
#   datetime.date(2019, 7, 7): 0.11639438788622312,
#   datetime.date(2019, 7, 8): 0.12450941112413863,
#   datetime.date(2019, 7, 9): 0.11498824545874337,
#   datetime.date(2019, 7, 10): 0.13460301781926176,
#   datetime.date(2019, 7, 11): 0.11984707597020816,
#   datetime.date(2019, 7, 12): 0.12037291124976689,
#   datetime.date(2019, 7, 13): 0.11087608170473538,
#   datetime.date(2019, 7, 14): 0.10979213880173677,
#   datetime.date(2019, 7, 15): 0.11228505640300701,
#   datetime.date(2019, 7, 16): 0.11508652160739488,
#   datetime.date(2019, 7, 17): 0.11881826047335203,
#   datetime.date(2019, 7, 18): 0.11333329566318974,
#   datetime.date(2019, 7, 19): 0.10795450695399136,
#   datetime.date(2019, 7, 20): 0.10124665776011678,
#   datetime.date(2019, 7, 21): 0.09166033372088256,
#   datetime.date(2019, 7, 22): 0.09998320581295547,
#   datetime.date(2019, 7, 23): 0.1055088734805808,
#   datetime.date(2019, 7, 24): 0.10138755346372834,
#   datetime.date(2019, 7, 25): 0.09892927950034704,
#   datetime.date(2019, 7, 26): 0.10113310891219607,
#   datetime.date(2019, 7, 27): 0.0970933851486814},
#  <Cryptocurrencies.ETHEREUM: 'ETH'>: {datetime.date(2019, 5, 28): 0.5279940015577775,
#   datetime.date(2019, 5, 29): 0.5528220241941635,
#   datetime.date(2019, 5, 30): 0.5201690014261563,
#   datetime.date(2019, 5, 31): 0.5313791884225286,
#   datetime.date(2019, 6, 1): 0.5487458680787598,
#   datetime.date(2019, 6, 2): 0.5306980037194724,
#   datetime.date(2019, 6, 3): 0.5230740347383226,
#   datetime.date(2019, 6, 4): 0.5287489192109736,
#   datetime.date(2019, 6, 5): 0.5039568838265281,
#   datetime.date(2019, 6, 6): 0.5187787748854632,
#   datetime.date(2019, 6, 7): 0.48887503662830994,
#   datetime.date(2019, 6, 8): 0.5444420604064462,
#   datetime.date(2019, 6, 9): 0.48225282370978967,
#   datetime.date(2019, 6, 10): 0.5485382748772886,
#   datetime.date(2019, 6, 11): 0.5383726669526436,
#   datetime.date(2019, 6, 12): 0.5242215639129587,
#   datetime.date(2019, 6, 13): 0.49490604764317425,
#   datetime.date(2019, 6, 14): 0.512588741113892,
#   datetime.date(2019, 6, 15): 0.5362084767238589,
#   datetime.date(2019, 6, 16): 0.534702027487783,
#   datetime.date(2019, 6, 17): 0.5388500548117102,
#   datetime.date(2019, 6, 18): 0.5165921789196231,
#   datetime.date(2019, 6, 19): 0.5255768024011075,
#   datetime.date(2019, 6, 20): 0.5491634517621891,
#   datetime.date(2019, 6, 21): 0.4962335877564651,
#   datetime.date(2019, 6, 22): 0.501102836250551,
#   datetime.date(2019, 6, 23): 0.4983880468801254,
#   datetime.date(2019, 6, 24): 0.5113856799945458,
#   datetime.date(2019, 6, 25): 0.539884212775358,
#   datetime.date(2019, 6, 26): 0.5209501501053311,
#   datetime.date(2019, 6, 27): 0.5081050391729051,
#   datetime.date(2019, 6, 28): 0.554310026893268,
#   datetime.date(2019, 6, 29): 0.4898174637091425,
#   datetime.date(2019, 6, 30): 0.4759102710203641,
#   datetime.date(2019, 7, 1): 0.5438738224861754,
#   datetime.date(2019, 7, 2): 0.5309828611047591,
#   datetime.date(2019, 7, 3): 0.4945986297446835,
#   datetime.date(2019, 7, 4): 0.49385740811150636,
#   datetime.date(2019, 7, 5): 0.5144151069937632,
#   datetime.date(2019, 7, 6): 0.4993848365675712,
#   datetime.date(2019, 7, 7): 0.45642067627504707,
#   datetime.date(2019, 7, 8): 0.5087192516863017,
#   datetime.date(2019, 7, 9): 0.5029106316481458,
#   datetime.date(2019, 7, 10): 0.4893714714197551,
#   datetime.date(2019, 7, 11): 0.5499636735062376,
#   datetime.date(2019, 7, 12): 0.48198392632020753,
#   datetime.date(2019, 7, 13): 0.4531057750067363,
#   datetime.date(2019, 7, 14): 0.4671550606514764,
#   datetime.date(2019, 7, 15): 0.4875169471030646,
#   datetime.date(2019, 7, 16): 0.5451447667444005,
#   datetime.date(2019, 7, 17): 0.509558914998607,
#   datetime.date(2019, 7, 18): 0.4772682406495741,
#   datetime.date(2019, 7, 19): 0.503835818066245,
#   datetime.date(2019, 7, 20): 0.4579899862381321,
#   datetime.date(2019, 7, 21): 0.4340734964360233,
#   datetime.date(2019, 7, 22): 0.4718832100514492,
#   datetime.date(2019, 7, 23): 0.46148266035863994,
#   datetime.date(2019, 7, 24): 0.531073318642772,
#   datetime.date(2019, 7, 25): 0.535336371183571,
#   datetime.date(2019, 7, 26): 0.4685103253388767,
#   datetime.date(2019, 7, 27): 0.45356563518462456},
#  <Cryptocurrencies.DOGECOIN: 'DOGE'>: {datetime.date(2019, 5, 28): 0.19773618353005057,
#   datetime.date(2019, 5, 29): 0.21906898665993224,
#   datetime.date(2019, 5, 30): 0.2158438510361675,
#   datetime.date(2019, 5, 31): 0.18742989839636776,
#   datetime.date(2019, 6, 1): 0.18066978911440412,
#   datetime.date(2019, 6, 2): 0.216131011626465,
#   datetime.date(2019, 6, 3): 0.16326868345466672,
#   datetime.date(2019, 6, 4): 0.15939708475366188,
#   datetime.date(2019, 6, 5): 0.1612138657099944,
#   datetime.date(2019, 6, 6): 0.16722121755435193,
#   datetime.date(2019, 6, 7): 0.16274599751868024,
#   datetime.date(2019, 6, 8): 0.15927167574998102,
#   datetime.date(2019, 6, 9): 0.1790147877640186,
#   datetime.date(2019, 6, 10): 0.19810719131729326,
#   datetime.date(2019, 6, 11): 0.1839179136723567,
#   datetime.date(2019, 6, 12): 0.1988052786633202,
#   datetime.date(2019, 6, 13): 0.19568083995516544,
#   datetime.date(2019, 6, 14): 0.18999992831938128,
#   datetime.date(2019, 6, 15): 0.17437312639441965,
#   datetime.date(2019, 6, 16): 0.2022253618253182,
#   datetime.date(2019, 6, 17): 0.16696695355943153,
#   datetime.date(2019, 6, 18): 0.19676202045889848,
#   datetime.date(2019, 6, 19): 0.17602457217131318,
#   datetime.date(2019, 6, 20): 0.19759112141739305,
#   datetime.date(2019, 6, 21): 0.16883094590472367,
#   datetime.date(2019, 6, 22): 0.1931248119561468,
#   datetime.date(2019, 6, 23): 0.180446383099032,
#   datetime.date(2019, 6, 24): 0.19295220925100692,
#   datetime.date(2019, 6, 25): 0.17144309621592796,
#   datetime.date(2019, 6, 26): 0.17776817819467786,
#   datetime.date(2019, 6, 27): 0.17491384438413865,
#   datetime.date(2019, 6, 28): 0.22845150568503153,
#   datetime.date(2019, 6, 29): 0.1834919869371639,
#   datetime.date(2019, 6, 30): 0.17760716187942438,
#   datetime.date(2019, 7, 1): 0.18467801618502586,
#   datetime.date(2019, 7, 2): 0.16966646384807582,
#   datetime.date(2019, 7, 3): 0.16972837654409603,
#   datetime.date(2019, 7, 4): 0.16689109847253575,
#   datetime.date(2019, 7, 5): 0.21104658602316578,
#   datetime.date(2019, 7, 6): 0.17204058530313848,
#   datetime.date(2019, 7, 7): 0.17074828919897492,
#   datetime.date(2019, 7, 8): 0.20281635006147858,
#   datetime.date(2019, 7, 9): 0.18050213139518048,
#   datetime.date(2019, 7, 10): 0.2098889358325926,
#   datetime.date(2019, 7, 11): 0.17606705083654284,
#   datetime.date(2019, 7, 12): 0.18582245581009832,
#   datetime.date(2019, 7, 13): 0.1587223724768883,
#   datetime.date(2019, 7, 14): 0.18066324505302755,
#   datetime.date(2019, 7, 15): 0.17274544973009118,
#   datetime.date(2019, 7, 16): 0.1705195753143827,
#   datetime.date(2019, 7, 17): 0.17956162776424459,
#   datetime.date(2019, 7, 18): 0.1616973209097379,
#   datetime.date(2019, 7, 19): 0.14879063713895235,
#   datetime.date(2019, 7, 20): 0.1571228463205261,
#   datetime.date(2019, 7, 21): 0.19951893268568202,
#   datetime.date(2019, 7, 22): 0.15854104881784872,
#   datetime.date(2019, 7, 23): 0.20420283777462295,
#   datetime.date(2019, 7, 24): 0.17104480558627738,
#   datetime.date(2019, 7, 25): 0.17074878395387288,
#   datetime.date(2019, 7, 26): 0.1821274634925569,
#   datetime.date(2019, 7, 27): 0.16667125512826325}}
