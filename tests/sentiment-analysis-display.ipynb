# %%
# %matplotlib notebook
import finndex

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## NLP

# %%
from finndex.util import webutil
from finndex.sentiment import nlp

txt = webutil.getCNNText("https://www.cnn.com/2019/07/09/investing/bitcoin-price/index.html")
nlp.displaySentimentTxt(txt)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Fear and Greed

# %%
from finndex.sentiment import fearandgreed
import datetime

gauge = fearandgreed.displayFearAndGreedDate(datetime.datetime.now() - datetime.timedelta(days=1))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Fundamental Analysis

# %%
from finndex.fundamental import coinmetrics

coinmetrics.plotAllCoinMetricsData()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Aggregate Analysis

# %%
from finndex.aggregate import instantaneous

manager = instantaneous.InstantaneousSentimentManager([instantaneous.StaticMetricType.FEAR_AND_GREED, 
                                                       instantaneous.StaticMetricType.TRENDS])
manager.displayGauge()

reading = manager.getReading()
# Out:
# The request failed: Google returned a response with code 400.
# <img src="data:image/png;base64,..." width="640">
# HBox(children=(VBox(children=(Label(value='StaticMetricType.FEAR_AND_GREED'), Label(value='StaticMetricType.TR…

# %%
from finndex.aggregate import historical
import datetime

historicalManager = historical.HistoricalSentimentManager([historical.HistoricalMetricType.FEAR_AND_GREED,
                                                           historical.HistoricalMetricType.TRENDS,
                                                           historical.HistoricalMetricType.BLOCK_COUNT,
                                                           historical.HistoricalMetricType.DAILY_ADDRESSES,
                                                           historical.HistoricalMetricType.TRANSACTION_CNT],
                                                          startDate = datetime.datetime.now() - datetime.timedelta(days=60),
                                                          endDate = datetime.datetime.now(),
                                                         unweightedKeywordsList=[historical.HistoricalMetricType.PRICE_USD])
historicalManager.displayGraph()
# Out:
# The request failed: Google returned a response with code 500.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-517292858782> in <module>
#      10                                                           endDate = datetime.datetime.now(),
#      11                                                          unweightedKeywordsList=[historical.HistoricalMetricType.PRICE_USD])
# ---> 12 historicalManager.displayGraph()
#
# ~/Code/Crypticko/Crypto-Sentiment-Tracker/cryptickoenv/lib/python3.7/site-packages/finndex/aggregate/historical.py in displayGraph(self)
#     138    '''
#     139    def displayGraph(self):
# --> 140       data = {'aggregateSentiment': self.getHistoricalSentiment()}
#     141
#     142       # Overlay any additional keywords provided
#
# ~/Code/Crypticko/Crypto-Sentiment-Tracker/cryptickoenv/lib/python3.7/site-packages/finndex/aggregate/historical.py in getHistoricalSentiment(self)
#     119                                       else -float('inf'), historicalReading.slider.getReading())] # add tuple with value (-infinity if nothing provided) and weight
#     120
# --> 121          values = self.removeGaps(sentimentByDate[date])
#     122
#     123          sentimentByDate[date] = 0
#
# TypeError: removeGaps() takes 1 positional argument but 2 were given
